# %%
import pandas as pd
import matplotlib.pyplot as plt

# 讀取同性結婚比例的資料
marriage_data = pd.read_csv('marriage.csv')
df = pd.read_csv('marriage.csv')

# 繪製折線圖
plt.figure(figsize=(10,6))
plt.plot(marriage_data['Year'], marriage_data['Percentage'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Percentage of Homosexuality Marriage')
plt.title('2019-2022 Percentage of Homosexuality Marriage in Taiwan')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 讀取同性結婚比例的資料
marriage_data = pd.read_csv('born.csv')
df = pd.read_csv('born.csv')

# 繪製折線圖
plt.figure(figsize=(10,6))
plt.plot(marriage_data['Year'], marriage_data['Number of Newborns'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Number of Newborns')
plt.title('2019-2022 Number of Newborns in Taiwan')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 讀取同性結婚比例和新生兒總數的資料
marriage_data = pd.read_csv('marriage.csv')
newborn_data = pd.read_csv('born.csv')
df = pd.read_csv('marriage.csv')
df = pd.read_csv('born.csv')

# 合併兩個資料集
merged_data = pd.merge(marriage_data, newborn_data, on='Year')

# 繪製散點圖
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['Percentage of Homosexuality Marriage'], merged_data['Number of Newborns'], marker='o')
plt.xlabel('Percentage of Homosexuality Marriage')
plt.ylabel('Number of Newborns')
plt.title('Relationship between the Percentage of Homosexuality Marriages and Number of Newborns')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Percentage of Homosexuality Marriage'
#
# The above exception was the direct cause of the following exception:
#
# ...
